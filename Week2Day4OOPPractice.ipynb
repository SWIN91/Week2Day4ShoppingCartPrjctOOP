# %%
class Loadtrinkets:
    def __init__(self):
        trinketdict = [
            'The Cloud Circuit:' "The power in this ring'll record yer eye's view fer twenty-fer hours...",
            'The Roar Band:' "This magical ring amplifies unheard sounds...use with caution!",
            'The Truncheon of Rataplan:' "Transform yer wand into a lightnin' breathin' dragon!",
            'The Baton of Rime:' "Freeze all moisture with'n a s'lected radius. Brrr...",
            'The Mantle of Apprehension:' 
            "This magical masterpiece traps its targets by transform'n fr'm ah cloak to ah cage!",
            'The Veneer of Mimicry:' "Once ya put on this cloak, ya can transfrm'nta anyth'n that's'round ya!"]
        print(trinketdict) 
             

            
class Cart:
    def __init__(self):
        self.cart = []
        
    def addTrinket(self, atrinket):  
        trinketdict = trinketdict = [
            'Cloud Circuit:' "The power in this ring'll record yer eye's view fer twenty-fer hours...",
            'Roar Band:' "This magical ring amplifies unheard sounds...use with caution!",
            'Truncheon of Rataplan:' "Transform yer wand into a lightnin' breathin' dragon!",
            'Baton of Rime:' "Freeze all moisture with'n a s'lected radius. Brrr...",
            'Mantle of Apprehension:' 
            "This magical masterpiece traps its targets by transform'n fr'm ah cloak to ah cage!",
            'Veneer of Mimicry:' "Once ya put on this cloak, ya can transfrm'nta anyth'n that's'round ya!"]
        if atrinket not in self.cart:
            self.cart.append(atrinket)   
            print(f"You added The {atrinket.title()} to your cart!")
        else:
            print("Hmmm...that didn't work.Try again ¯\_(ツ)_/¯")
    
    def vanquishTrinket(self, atrinket): 
        if atrinket not in self.cart:
            print("Nothing to vanquish!")
        if atrinket in self.cart:
            self.cart.remove(atrinket)
            print(f"You removed The {atrinket.title()} from your cart.")
    
    def admireTrinket(self):
        if self.cart == []:
            print("Nothing to admire!") 
        else:
            print(f"Here's what ya'v got so far: {self.cart}")

            
class Main:
    @classmethod
    def run(self):
        cart = Cart()
        products = Loadtrinkets ()
        while True:

            response = input("""\t
           ,===:'.,            `-._
                `:.`---.__         `-._
                  `:.     `--.         `.
                    \.        `.         `.
            (,,(,    \.         `.   ____,-`.,
         (,'     `/   \.   ,--.___`.'
     ,  ,'  ,--.  `,   \.;'         `
      `{D, {    \  :    \;
        V,,'    /  /    //
        j;;    /  ,' ,-//.    ,---.      ,
        \;'   /  ,' /  _  \  /  _  \   ,'/
              \   `'  / \  `'  / \  `.' /
               `.___,'   `.__,'   `.__,' 

            """ + "\tWelcome to Trinkets!" + "\nPress '1' to add, '2' to vanquish, 3 to regard or 4 to depart: ")                  
            while response not in ['1','2','3','4']:
                response = input("Hmmm...that didn't work.Try again ¯\_(ツ)_/¯")
            if response == '1':
                atrinket = input("""
                What would ya like to add? Type tha name of tha item in all small letters.
                (Fer x'ample: type 'cloud circuit' to add the Cloud Circuit to yer cart.
                You can only add one of each it'm to yer cart, tho.
                Gotta share ma' wares with other travel'rs!
                """)
                cart.addTrinket(atrinket)
            if response == '2':
                response = input("""
                What would you like to vanquish? Type tha name of tha item in all small letters.
                (Fer x'ample: type 'cloud circuit' to vanquish the Cloud Circuit fr'm yer cart.
                """)
                cart.vanquishTrinket(atrinket)
            if response == '3':
                cart.admireTrinket()
            if response == '4':
                print ("""\n\tThank you! Have a nice day!


           ,===:'.,            `-._
                `:.`---.__         `-._
                  `:.     `--.         `.
                    \.        `.         `.
            (,,(,    \.         `.   ____,-`.,
         (,'     `/   \.   ,--.___`.'
     ,  ,'  ,--.  `,   \.;'         `
      `{D, {    \  :    \;
        V,,'    /  /    //
        j;;    /  ,' ,-//.    ,---.      ,
        \;'   /  ,' /  _  \  /  _  \   ,'/
              \   `'  / \  `'  / \  `.' /
               `.___,'   `.__,'   `.__,'  

                """)
                break
Main.run()
# Out:
# ["The Cloud Circuit:The power in this ring'll record yer eye's view fer twenty-fer hours...", 'The Roar Band:This magical ring amplifies unheard sounds...use with caution!', "The Truncheon of Rataplan:Transform yer wand into a lightnin' breathin' dragon!", "The Baton of Rime:Freeze all moisture with'n a s'lected radius. Brrr...", "The Mantle of Apprehension:This magical masterpiece traps its targets by transform'n fr'm ah cloak to ah cage!", "The Veneer of Mimicry:Once ya put on this cloak, ya can transfrm'nta anyth'n that's'round ya!"]
#
#            ,===:'.,            `-._
#                 `:.`---.__         `-._
#                   `:.     `--.         `.
#                     \.        `.         `.
#             (,,(,    \.         `.   ____,-`.,
#          (,'     `/   \.   ,--.___`.'
#      ,  ,'  ,--.  `,   \.;'         `
#       `{D, {    \  :    \;
#         V,,'    /  /    //
#         j;;    /  ,' ,-//.    ,---.      ,
#         \;'   /  ,' /  _  \  /  _  \   ,'/
# ...
